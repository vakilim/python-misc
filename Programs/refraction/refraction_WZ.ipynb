# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sin, cos, asin, tan

# %%
nw = 1.33
na = 1
d = 8
#alpha = 70*np.pi/180 #DEG TO RAD

# d = np.linspace(0,10,180)
alpha = np.linspace(0,np.pi/2,100)
denominator = np.sqrt(1-(na/nw*np.sin(alpha))**2)

L = nw*2*d/denominator-na*2*d*na/nw*np.sin(alpha)*np.sin(alpha)/denominator

# %%
# %matplotlib notebook
plt.figure()
plt.plot(alpha*180/np.pi,L)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
def calculate_pathdifference(d, na, nw, alpha_deg):
    
    # Convert theta from degrees to radians
    alpha_rad = np.deg2rad(alpha_deg)
    cos_alpha_prime = np.sqrt(1-(na/nw*np.sin(alpha))**2)
    
    # Calculate the expression    
    L1 = nw*2*d/cos_alpha_prime - na*2*d*(na/nw)*np.sin(alpha)*np.sin(alpha)/cos_alpha_prime
    return L1

# %%
alpha_deg = np.linspace(0,90,100)

L1 = calculate_pathdifference(d, na, nw, alpha_deg)

# %%
# %matplotlib notebook
plt.figure()
plt.plot(alpha*180/np.pi,L1)
# Out:
# <img src="data:image/png;base64,..." width="639.2">
